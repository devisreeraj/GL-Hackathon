# %%
import pandas as pd

# %%
freq_feat = pd.read_csv('Train Data/Train Data Zip/frequency_domain_features_train.csv', delimiter=' *, *', engine='python')
heartrate_feat = pd.read_csv('Train Data/Train Data Zip/heart_rate_non_linear_features_train.csv', delimiter=' *, *', engine='python')
time_feat = pd.read_csv('Train Data/Train Data Zip/time_domain_features_train.csv', delimiter=' *, *', engine='python')

# %%
freq_feat.head()
# Out:
#                                    uuid          VLF    VLF_PCT           LF  \
# 0  89df2855-56eb-4706-a23b-b39363dd605a  2661.894136  72.203287  1009.249419
# 1  80c795e4-aa56-4cc0-939c-19634b89cbb2  2314.265450  76.975728   690.113275
# 2  c2d5d102-967c-487d-88f2-8b005a449f3e  1373.887112  51.152225  1298.222619
# 3  37eabc44-1349-4040-8896-0d113ad4811f  2410.357408  70.180308  1005.981659
# 4  aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  1151.177330  43.918366  1421.782051
#
#       LF_PCT      LF_NU         HF    HF_PCT     HF_NU           TP  \
# 0  27.375666  98.485263  15.522603  0.421047  1.514737  3686.666157
# 1  22.954139  99.695397   2.108525  0.070133  0.304603  3006.487251
# 2  48.335104  98.950472  13.769729  0.512671  1.049528  2685.879461
# 3  29.290305  98.224706  18.181913  0.529387  1.775294  3434.520980
# 4  54.242160  96.720007  48.215822  1.839473  3.279993  2621.175204
#
#         LF_HF     HF_LF
# 0   65.018055  0.015380
# 1  327.296635  0.003055
# ...

# %%
heartrate_feat.head()
# Out:
#                                    uuid        SD1         SD2    sampen  \
# 0  89df2855-56eb-4706-a23b-b39363dd605a  11.001565  199.061782  2.139754
# 1  80c795e4-aa56-4cc0-939c-19634b89cbb2   9.170129  114.634458  2.174499
# 2  c2d5d102-967c-487d-88f2-8b005a449f3e  11.533417  118.939253  2.135350
# 3  37eabc44-1349-4040-8896-0d113ad4811f  11.119476  127.318597  2.178341
# 4  aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  13.590641   87.718281  2.221121
#
#      higuci  datasetId     condition
# 0  1.163485          2     no stress
# 1  1.084711          2  interruption
# 2  1.176315          2  interruption
# 3  1.179688          2     no stress
# 4  1.249612          2     no stress

# %%
time_feat.head()
# Out:
#       MEAN_RR   MEDIAN_RR        SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0  885.157845  853.763730  140.972741  15.554505  15.553371    9.063146
# 1  939.425371  948.357865   81.317742  12.964439  12.964195    6.272369
# 2  898.186047  907.006860   84.497236  16.305279  16.305274    5.182201
# 3  881.757865  893.460030   90.370537  15.720468  15.720068    5.748591
# 4  809.625331  811.184865   62.766242  19.213819  19.213657    3.266724
#
#           HR      pNN25     pNN50      KURT      SKEW  MEAN_REL_RR  \
# 0  69.499952  11.133333  0.533333 -0.856554  0.335218    -0.000203
# 1  64.363150   5.600000  0.000000 -0.408190 -0.155286    -0.000059
# 2  67.450066  13.066667  0.200000  0.351789 -0.656813    -0.000011
# 3  68.809562  11.800000  0.133333 -0.504947 -0.386138     0.000112
# 4  74.565728  20.200000  0.200000 -0.548408 -0.154252    -0.000100
#
#    MEDIAN_REL_RR  SDRR_REL_RR  RMSSD_REL_RR  SDSD_REL_RR  SDRR_RMSSD_REL_RR  \
# ...

# %%
print('Shape of frequency_domain_features : ', freq_feat.shape)
print('Shape of heart_rate_non_linear_features : ', heartrate_feat.shape)
print('Shape of time_domain_features : ', time_feat.shape)
# Out:
# Shape of frequency_domain_features :  (369289, 12)
# Shape of heart_rate_non_linear_features :  (369289, 7)
# Shape of time_domain_features :  (369289, 20)

# %%
Data = freq_feat.merge(heartrate_feat, on='uuid', how='inner', suffixes=('_1', '_2'))
Data = Data.merge(time_feat, on='uuid', how='inner', suffixes=('_1', '_2'))
Data.head()
# Out:
#                                    uuid          VLF    VLF_PCT           LF  \
# 0  89df2855-56eb-4706-a23b-b39363dd605a  2661.894136  72.203287  1009.249419
# 1  80c795e4-aa56-4cc0-939c-19634b89cbb2  2314.265450  76.975728   690.113275
# 2  c2d5d102-967c-487d-88f2-8b005a449f3e  1373.887112  51.152225  1298.222619
# 3  37eabc44-1349-4040-8896-0d113ad4811f  2410.357408  70.180308  1005.981659
# 4  aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  1151.177330  43.918366  1421.782051
#
#       LF_PCT      LF_NU         HF    HF_PCT     HF_NU           TP  ...  \
# 0  27.375666  98.485263  15.522603  0.421047  1.514737  3686.666157  ...
# 1  22.954139  99.695397   2.108525  0.070133  0.304603  3006.487251  ...
# 2  48.335104  98.950472  13.769729  0.512671  1.049528  2685.879461  ...
# 3  29.290305  98.224706  18.181913  0.529387  1.775294  3434.520980  ...
# 4  54.242160  96.720007  48.215822  1.839473  3.279993  2621.175204  ...
#
# ...

# %%
Data.shape
# Out:
# (369289, 37)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 369289 entries, 0 to 369288
# Data columns (total 37 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   uuid               369289 non-null  object
#  1   VLF                369289 non-null  float64
#  2   VLF_PCT            369289 non-null  float64
#  3   LF                 369289 non-null  float64
#  4   LF_PCT             369289 non-null  float64
#  5   LF_NU              369289 non-null  float64
#  6   HF                 369289 non-null  float64
#  7   HF_PCT             369289 non-null  float64
#  8   HF_NU              369289 non-null  float64
#  9   TP                 369289 non-null  float64
#  10  LF_HF              369289 non-null  float64
#  11  HF_LF              369289 non-null  float64
#  12  SD1                369289 non-null  float64
#  13  SD2                369289 non-null  float64
#  14  sampen             369289 non-null  float64
# ...

# %%
Data[['HR','condition']]
# Out:
#                HR     condition
# 0       69.499952     no stress
# 1       64.363150  interruption
# 2       67.450066  interruption
# 3       68.809562     no stress
# 4       74.565728     no stress
# ...           ...           ...
# 369284  83.384647     no stress
# 369285  61.314243     no stress
# 369286  59.028594     no stress
# 369287  75.978628     no stress
# 369288  74.197905     no stress
#
# [369289 rows x 2 columns]

# %%
Data.columns
# Out:
# Index(['uuid', 'VLF', 'VLF_PCT', 'LF', 'LF_PCT', 'LF_NU', 'HF', 'HF_PCT',
#        'HF_NU', 'TP', 'LF_HF', 'HF_LF', 'SD1', 'SD2', 'sampen', 'higuci',
#        'datasetId', 'condition', 'MEAN_RR', 'MEDIAN_RR', 'SDRR', 'RMSSD',
#        'SDSD', 'SDRR_RMSSD', 'HR', 'pNN25', 'pNN50', 'KURT', 'SKEW',
#        'MEAN_REL_RR', 'MEDIAN_REL_RR', 'SDRR_REL_RR', 'RMSSD_REL_RR',
#        'SDSD_REL_RR', 'SDRR_RMSSD_REL_RR', 'KURT_REL_RR', 'SKEW_REL_RR'],
#       dtype='object')

# %%
column_names = list(Data.columns.values)
column_names
# Out:
# ['uuid',
#  'VLF',
#  'VLF_PCT',
#  'LF',
#  'LF_PCT',
#  'LF_NU',
#  'HF',
#  'HF_PCT',
#  'HF_NU',
#  'TP',
#  'LF_HF',
#  'HF_LF',
#  'SD1',
#  'SD2',
#  'sampen',
#  'higuci',
#  'datasetId',
#  'condition',
#  'MEAN_RR',
#  'MEDIAN_RR',
#  'SDRR',
#  'RMSSD',
#  'SDSD',
#  'SDRR_RMSSD',
#  'HR',
#  'pNN25',
#  'pNN50',
#  'KURT',
#  'SKEW',
#  'MEAN_REL_RR',
#  'MEDIAN_REL_RR',
#  'SDRR_REL_RR',
#  'RMSSD_REL_RR',
#  'SDSD_REL_RR',
#  'SDRR_RMSSD_REL_RR',
#  'KURT_REL_RR',
#  'SKEW_REL_RR']

# %%
revised_columns = [ elem for elem in column_names if elem not in ['uuid','condition','HR']] #column_names.remove('uuid','condition','HR')
revised_columns
# Out:
# ['VLF',
#  'VLF_PCT',
#  'LF',
#  'LF_PCT',
#  'LF_NU',
#  'HF',
#  'HF_PCT',
#  'HF_NU',
#  'TP',
#  'LF_HF',
#  'HF_LF',
#  'SD1',
#  'SD2',
#  'sampen',
#  'higuci',
#  'datasetId',
#  'MEAN_RR',
#  'MEDIAN_RR',
#  'SDRR',
#  'RMSSD',
#  'SDSD',
#  'SDRR_RMSSD',
#  'pNN25',
#  'pNN50',
#  'KURT',
#  'SKEW',
#  'MEAN_REL_RR',
#  'MEDIAN_REL_RR',
#  'SDRR_REL_RR',
#  'RMSSD_REL_RR',
#  'SDSD_REL_RR',
#  'SDRR_RMSSD_REL_RR',
#  'KURT_REL_RR',
#  'SKEW_REL_RR']

# %%
len(revised_columns)
# Out:
# 34

# %%
kailas = revised_columns[:11]
kailas
# Out:
# ['VLF',
#  'VLF_PCT',
#  'LF',
#  'LF_PCT',
#  'LF_NU',
#  'HF',
#  'HF_PCT',
#  'HF_NU',
#  'TP',
#  'LF_HF',
#  'HF_LF']

# %%
len(kailas)
# Out:
# 11

# %%
nidhi = revised_columns[11:22]
nidhi
# Out:
# ['SD1',
#  'SD2',
#  'sampen',
#  'higuci',
#  'datasetId',
#  'MEAN_RR',
#  'MEDIAN_RR',
#  'SDRR',
#  'RMSSD',
#  'SDSD',
#  'SDRR_RMSSD']

# %%
len(nidhi)
# Out:
# 11

# %%
devi = revised_columns[22:]
devi
# Out:
# ['pNN25',
#  'pNN50',
#  'KURT',
#  'SKEW',
#  'MEAN_REL_RR',
#  'MEDIAN_REL_RR',
#  'SDRR_REL_RR',
#  'RMSSD_REL_RR',
#  'SDSD_REL_RR',
#  'SDRR_RMSSD_REL_RR',
#  'KURT_REL_RR',
#  'SKEW_REL_RR']

# %%
len(devi)
# Out:
# 12
